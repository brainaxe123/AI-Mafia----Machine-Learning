# %% [markdown]
# # <center>Introduction to Pandas</center>
#
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
#
# ## Installation
#
# Simply,
# ```
# pip install pandas
# ```
#
#
# ## Reading data from a CSV file
#
# You can read data from a CSV file using the ``read_csv`` function. By default, it assumes that the fields are comma-separated.

# %%
 import pandas as pd

# %% [markdown]
# >The `imdb.csv` dataset contains Highest Rated IMDb "Top 1000" Titles.

# %%
# load imdb dataset as pandas dataframe
import pandas as pd
imdb_df = pd.read_csv("D:/python libraries/IMDB-Movie-Data.csv")

# %%
# show first 5 rows of imdb_df
imdb_df.head(1000)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# >The `bikes.csv` dataset contains information about the number of bicycles that used certain bicycle lanes in Montreal in the year 2012.

# %%
# load bikes dataset as pandas dataframe
import pandas as pd
bikes_df = pd.read_csv('D:/python libraries/bikes.csv' , sep = ';' , parse_dates=['Date'])

# %%
# show first 3 rows of bikes_df
import pandas as pd
bikes_df.head(3)
# Out:
#         Date  Berri 1  Br?beuf (donn?es non disponibles)  \
# 0 2012-01-01       35                                NaN
# 1 2012-02-01       83                                NaN
# 2 2012-03-01      135                                NaN
#
#    C?te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
#
#    Rachel1  St-Urbain (donn?es non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# 2       58                                  NaN

# %% [markdown]
# ## Selecting columns
#
# When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.

# %%
# list columns of imdb_df
imdb_df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# what are the datatypes of values in columns
imdb_df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
# list first 5 movie titles
import pandas as pd
imdb_df = pd.read_csv("D:/python libraries/IMDB-Movie-Data.csv")
imdb_df['Title'].head(5)
# Out:
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# Name: Title, dtype: object

# %%
# show only movie title and genre
imdb_df[['Title' , 'Genre']]
# Out:
#                        Title                     Genre
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery
# 996          Hostel: Part II                    Horror
# 997   Step Up 2: The Streets       Drama,Music,Romance
# 998             Search Party          Adventure,Comedy
# 999               Nine Lives     Comedy,Family,Fantasy
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Understanding columns
#
# On the inside, the type of a column is ``pd.Series`` and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**.

# %%
# show the type of duration column
import pandas as pd
imdb_df = pd.read_csv("D:/python libraries/IMDB-Movie-Data.csv")
imdb_df['Runtime (Minutes)'].dtype
# Out:
# dtype('int64')

# %%
# show duration values of movies as numpy arrays
imdb_df['Runtime (Minutes)'].values
# Out:
# array([121, 124, 117, 108, 123, 103, 128,  89, 141, 116, 133, 127, 133,
#        107, 109,  87, 139, 123, 118, 116, 120, 137, 108,  92, 120,  83,
#        159,  99, 100, 115, 111, 116, 144, 108, 107, 147, 169, 115, 132,
#        113,  89, 111,  73, 115,  99, 136, 132,  91, 122, 130, 136,  91,
#        118, 101, 152, 161,  88, 106, 117,  96, 151,  86, 112, 125, 130,
#        129, 133, 120, 106, 107, 133, 124, 108,  97, 108, 169, 143, 153,
#        151, 116, 148, 118, 180, 149, 137, 124, 129, 162, 187, 128, 153,
#        123, 146, 114, 141, 116, 106,  90, 105, 151, 132, 115, 144, 106,
#        116, 102, 120, 110, 105, 108,  89, 134, 118, 117, 130, 105, 118,
#        161, 104,  97, 127, 139,  98,  86, 164, 106, 165,  96, 108, 156,
#        139, 125,  86, 107, 130, 140, 122, 143, 138, 148, 127,  94, 130,
#        118, 165, 144, 104, 162, 113, 121, 117, 142,  88, 121,  91,  94,
#        131, 118, 112, 121, 106,  90, 132, 118, 144, 122, 129, 109, 144,
# ...

# %% [markdown]
# ## Applying functions to columns
#
# Use `.apply` function to apply any function to each element of a column.

# %%
# convert all the movie titles to uppercase
to_upper = lambda x : x.upper()
imdb_df['Title'].apply(to_upper)
# Out:
# 0      GUARDIANS OF THE GALAXY
# 1                   PROMETHEUS
# 2                        SPLIT
# 3                         SING
# 4                SUICIDE SQUAD
#                 ...
# 995       SECRET IN THEIR EYES
# 996            HOSTEL: PART II
# 997     STEP UP 2: THE STREETS
# 998               SEARCH PARTY
# 999                 NINE LIVES
# Name: Title, Length: 1000, dtype: object

# %% [markdown]
# ## Plotting a column
#
# Use ``.plot()`` function!

# %%
# plot the bikers travelling to Berri1 over the year
import pandas as pd
import matplotlib.pyplot as plt
bikes_df = pd.read_csv('D:/python libraries/bikes.csv' , sep = ';' , parse_dates=['Date'])
bikes_df['Berri 1'].plot()
plt.show()

# %%
# plot all the columns of bikes_df
bikes_df[['Berri 1' , 'Maisonneuve 1' ]].plot( subplots = True)
plt.show()

# %% [markdown]
# ## Value counts
#
# Get count of unique values in a particular column/Series.

# %%
# what are the unique genre in imdb_df?
imdb_df['Genre'].value_counts()
# Out:
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Action,Fantasy,War          1
# Action,Biography,Crime      1
# Comedy,Western              1
# Comedy,Fantasy,Romance      1
# Action,Comedy,Mystery       1
# Name: Genre, Length: 207, dtype: int64

# %%
# plotting value counts of unique genres as a bar chart
imdb_df['Genre'].value_counts().plot.bar(figsize=(250,100))
plt.axis([0,207,0,55])
plt.show()

# %%
# plotting value counts of unique genres as a pie chart
imdb_df['Genre'].value_counts().plot.pie()

# %% [markdown]
# ## Index
#
# ### DATAFRAME = COLUMNS + INDEX + ND DATA
#
# ### SERIES = INDEX + 1-D DATA
#
# **Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.
#
# > Every row is uniquely identified by its index value.

# %%
# show index of bikes_df
bikes_df.index
# Out:
# RangeIndex(start=0, stop=310, step=1)

# %%
# get row for date 2012-01-01
bikes_df.loc[bikes_df['Date'] == '2012-01-01']
# Out:
#         Date  Berri 1  Br?beuf (donn?es non disponibles)  \
# 0 2012-01-01       35                                NaN
#
#    C?te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
#
#    Rachel1  St-Urbain (donn?es non disponibles)  Weekday
# 0       16                                  NaN        6

# %% [markdown]
# #### To get row by integer index:
#
# Use ``.iloc[]`` for purely integer-location based indexing for selection by position.

# %%
# show 11th row of imdb_df using iloc
imdb_df.iloc[10]
# Out:
# Rank                                                                 11
# Title                           Fantastic Beasts and Where to Find Them
# Genre                                          Adventure,Family,Fantasy
# Description           The adventures of writer Newt Scamander in New...
# Director                                                    David Yates
# Actors                Eddie Redmayne, Katherine Waterston, Alison Su...
# Year                                                               2016
# Runtime (Minutes)                                                   133
# Rating                                                              7.5
# Votes                                                            232072
# Revenue (Millions)                                               234.02
# Metascore                                                            66
# Name: 10, dtype: object

# %% [markdown]
# ## Selecting rows where column has a particular value

# %%
# select only those movies where genre is adventure
imdb_df.loc[imdb_df['Genre'] == 'Adventure']
# Out:
#      Rank  Title      Genre  \
# 949   950  Kicks  Adventure
#
#                                            Description        Director  \
# 949  Brandon is a 15 year old whose dream is a pair...  Justin Tipping
#
#                                                 Actors  Year  \
# 949  Jahking Guillory, Christopher Jordan Wallace,C...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 949                 80     6.1   2417                0.15       69.0

# %%
# which genre has highest number of movies with star rating above 8 and duration more than 130 minutes?
import pandas as pd
import matplotlib.pyplot as plt
bikes_df = pd.read_csv('D:/python libraries/bikes.csv' , sep = ';' , parse_dates=['Date'])
#rating = imdb_df[imdb_df['Rating'] >= 8]

#duration = imdb_df[imdb_df['Runtime (Minutes)'] >= 130]

imdb_new=imdb_df[(imdb_df['Rating'] > 8) & (imdb_df['Runtime (Minutes)'] > 130)]
imdb_new['Genre'].value_counts()
#imdb_df['Genre'].value_counts()
# Out:
# Biography,Drama,History      2
# Crime,Drama,Mystery          2
# Drama                        2
# Adventure,Drama,Sci-Fi       1
# Drama,Family,Music           1
# Crime,Drama,Thriller         1
# Adventure,Drama,War          1
# Action,Biography,Drama       1
# Drama,Western                1
# Biography,Comedy,Crime       1
# Action,Drama,Sport           1
# Comedy,Drama,Romance         1
# Drama,Mystery,War            1
# Mystery,Thriller             1
# Drama,Mystery,Romance        1
# Drama,Thriller               1
# Comedy,Drama                 1
# Adventure,Biography,Drama    1
# Action,Adventure,Fantasy     1
# Drama,History                1
# Action,Adventure,Drama       1
# Action,Adventure,Sci-Fi      1
# Action,Sci-Fi                1
# Action,Crime,Drama           1
# Action,Thriller              1
# Name: Genre, dtype: int64

# %% [markdown]
# ## Adding a new column to DataFrame

# %%
# add a weekday column to bikes_df
b2=bikes_df[['Date','Berri 1']]
b3=b2['Date'].dt.weekday

bikes_df['Weekday']=b3
bikes_df[['Berri 1' , 'Weekday']]
# Out:
#      Berri 1  Weekday
# 0         35        6
# 1         83        2
# 2        135        3
# 3        144        6
# 4        197        1
# ..       ...      ...
# 305     2405        2
# 306     1582        5
# 307      844        6
# 308      966        2
# 309     2247        4
#
# [310 rows x 2 columns]

# %% [markdown]
# ## Deleting an existing column from DataFrame

# %%
# remove column 'Unnamed: 1' from bikes_df

bikes_df.drop(columns='Maisonneuve 1')
# Out:
#           Date  Berri 1  Br?beuf (donn?es non disponibles)  \
# 0   2012-01-01       35                                NaN
# 1   2012-02-01       83                                NaN
# 2   2012-03-01      135                                NaN
# 3   2012-04-01      144                                NaN
# 4   2012-05-01      197                                NaN
# ..         ...      ...                                ...
# 305 2012-01-11     2405                                NaN
# 306 2012-02-11     1582                                NaN
# 307 2012-03-11      844                                NaN
# 308 2012-04-11      966                                NaN
# 309 2012-05-11     2247                                NaN
#
#      C?te-Sainte-Catherine  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# 0                        0             51       26            10       16
# 1                        1            153       53             6       43
# ...

# %% [markdown]
# ## Deleting a row in DataFrame

# %%
# remove row no. 1 from bikes_df
bikes_df.drop([0],axis=0)
# Out:
#           Date  Berri 1  Br?beuf (donn?es non disponibles)  \
# 1   2012-02-01       83                                NaN
# 2   2012-03-01      135                                NaN
# 3   2012-04-01      144                                NaN
# 4   2012-05-01      197                                NaN
# 5   2012-06-01      146                                NaN
# ..         ...      ...                                ...
# 305 2012-01-11     2405                                NaN
# 306 2012-02-11     1582                                NaN
# 307 2012-03-11      844                                NaN
# 308 2012-04-11      966                                NaN
# 309 2012-05-11     2247                                NaN
#
#      C?te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 1                        1             68            153       53
# 2                        2            104            248       89
# ...

# %% [markdown]
# ## Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# - Splitting the Object
#
# - Applying a function
#
# - Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# - **Aggregation** − computing a summary statistic
#
# - **Transformation** − perform some group-specific operation
#
# - **Filtration** − discarding the data with some condition

# %%
# group imdb_df by movie genres
a=imdb_df.groupby('Genre')
a['Gnre'].first()

# %%
# get crime movies group
a.get_group('Action,Adventure,Crime')
# Out:
#      Rank                               Title  \
# 149   150                             Inferno
# 163   164         Jack Reacher: Never Go Back
# 281   282                     Sherlock Holmes
# 414   415              Mechanic: Resurrection
# 465   466  Sherlock Holmes: A Game of Shadows
# 901   902                   Snakes on a Plane
#
#                                            Description        Director  \
# 149  When Robert Langdon wakes up in an Italian hos...      Ron Howard
# 163  Jack Reacher must uncover the truth behind a m...    Edward Zwick
# 281  Detective Sherlock Holmes and his stalwart par...     Guy Ritchie
# 414  Arthur Bishop thought he had put his murderous...   Dennis Gansel
# 465  Sherlock Holmes and his sidekick Dr. Watson jo...     Guy Ritchie
# 901  An FBI agent takes on a plane full of deadly a...  David R. Ellis
#
#                                                 Actors  Year  \
# 149  Tom Hanks, Felicity Jones, Irrfan Khan, Ben Fo...  2016
# ...

# %%
# get mean of movie durations for each group
b=a['Runtime (Minutes)'].mean()
b
# Out:
# Genre
# Action                         88.000000
# Action,Adventure              124.333333
# Action,Adventure,Biography    131.500000
# Action,Adventure,Comedy       109.642857
# Action,Adventure,Crime        116.500000
#                                  ...
# Romance,Sci-Fi,Thriller       106.000000
# Sci-Fi                        106.500000
# Sci-Fi,Thriller                91.000000
# Thriller                       95.222222
# Thriller,War                  106.000000
# Name: Runtime (Minutes), Length: 207, dtype: float64

# %%
# change duration of all movies in a particular genre to mean duration of the group
to_mean = lambda x : b
imdb_df['Runtime (Minutes)'].loc[imdb_df['Genre'] == 'Action'].apply(to_mean)
#imdb_df
#imdb_df.loc
# Out:
# Genre  Action  Action,Adventure  Action,Adventure,Biography  \
# 123      88.0        124.333333                       131.5
# 580      88.0        124.333333                       131.5
#
# Genre  Action,Adventure,Comedy  Action,Adventure,Crime  \
# 123                 109.642857                   116.5
# 580                 109.642857                   116.5
#
# Genre  Action,Adventure,Drama  Action,Adventure,Family  \
# 123                124.166667                    105.5
# 580                124.166667                    105.5
#
# Genre  Action,Adventure,Fantasy  Action,Adventure,Horror  \
# 123                  118.148148                    106.5
# 580                  118.148148                    106.5
#
# Genre  Action,Adventure,Mystery  ...  Mystery,Romance,Thriller  \
# 123                       128.6  ...                     108.0
# 580                       128.6  ...                     108.0
#
# ...

# %%
# drop groups/genres that do not have average movie duration greater than 120.

# %%
# group weekday wise bikers count
b2=bikes_df[['Date','Berri 1']]
b3=b2['Date'].dt.weekday

bikes_df['Weekday']=b3
bikes_df[['Berri 1' , 'Weekday']]
a=bikes_df.groupby('Weekday')
a.first()
# Out:
#               Date  Berri 1  Br?beuf (donn?es non disponibles)  \
# Weekday
# 0       2012-10-01      397                                NaN
# 1       2012-05-01      197                                NaN
# 2       2012-02-01       83                                NaN
# 3       2012-03-01      135                                NaN
# 4       2012-06-01      146                                NaN
# 5       2012-09-01      244                                NaN
# 6       2012-01-01       35                                NaN
#
#          C?te-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# Weekday
# 0                            3            238            563      275
# 1                            2            124            330       97
# 2                            1             68            153       53
# 3                            2            104            248       89
# 4                            0             98            244       86
# ...

# %%
# get weekday wise biker count
a[[ 'Berri 1']].first()
# Out:
#          Berri 1
# Weekday
# 0            397
# 1            197
# 2             83
# 3            135
# 4            146
# 5            244
# 6             35

# %%
# plot weekday wise biker count for 'Berri1'
a['Berri 1'].plot()
plt.show()

# %% [markdown]
# ![](https://memegenerator.net/img/instances/500x/73988569/pythonpandas-is-easy-import-and-go.jpg)
